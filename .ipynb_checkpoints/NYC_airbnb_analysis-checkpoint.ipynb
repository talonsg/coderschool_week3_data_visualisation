# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import math
import geopandas as gpd
import csv

#import geoplot as gplt


from datetime import datetime
from pylab import *
from shapely.ops import nearest_points

# %%
df = pd.read_csv('clean_nyc_airbnb.csv')
df2 = pd.read_csv('clean_nyc_sale.csv')

# %%
#CALCULATE ANNUAL EARNING FROM AIRBNB
#assume the given occupnacy percentage

df['annual_earn'] = df['price'] * df['occupancy_%']/100 * 365
print(df2['neighbourhood'].unique())
df2.loc[df2['neighbourhood'] == 'SOUTHBRIDGE']
# Out:
# ['CHELSEA' 'CLINTON' 'FASHION' 'FLATIRON' 'GRAMERCY'
#  'GREENWICH VILLAGE-CENTRAL' 'GREENWICH VILLAGE-WEST' 'HARLEM-CENTRAL'
#  'JAVITS CENTER' 'LOWER EAST SIDE' 'MIDTOWN CBD' 'MIDTOWN EAST'
#  'MIDTOWN WEST' 'SOUTHBRIDGE' 'UPPER EAST SIDE (59-79)'
#  'UPPER EAST SIDE (79-96)' 'UPPER WEST SIDE (59-79)'
#  'UPPER WEST SIDE (79-96)' 'UPPER WEST SIDE (96-116)' 'BELMONT'
#  'BRONXDALE' 'CASTLE HILL/UNIONPORT' 'COUNTRY CLUB'
#  'HIGHBRIDGE/MORRIS HEIGHTS' 'MELROSE/CONCOURSE' 'MORRIS PARK/VAN NEST'
#  'MORRISANIA/LONGWOOD' 'MOUNT HOPE/MOUNT EDEN' 'PARKCHESTER'
#  'PELHAM PARKWAY NORTH' 'RIVERDALE' 'SOUNDVIEW' 'WAKEFIELD' 'WESTCHESTER'
#  'BATH BEACH' 'BAY RIDGE' 'BEDFORD STUYVESANT' 'BENSONHURST'
#  'BOROUGH PARK' 'BROWNSVILLE' 'BUSHWICK' 'CANARSIE' 'CONEY ISLAND'
#  'CROWN HEIGHTS' 'DOWNTOWN-FULTON FERRY' 'DOWNTOWN-FULTON MALL'
#  'DYKER HEIGHTS' 'EAST NEW YORK' 'FLATBUSH-CENTRAL' 'FLATBUSH-EAST'
#  'FLATBUSH-LEFFERTS GARDEN' 'FLATBUSH-NORTH' 'FORT GREENE'
#  'GERRITSEN BEACH' 'GOWANUS' 'GRAVESEND' 'MADISON' 'MANHATTAN BEACH'
#  'MIDWOOD' 'OCEAN HILL' 'OCEAN PARKWAY-NORTH' 'OCEAN PARKWAY-SOUTH'
#  'OLD MILL BASIN' 'PARK SLOPE' 'PARK SLOPE SOUTH' 'PROSPECT HEIGHTS'
#  'SHEEPSHEAD BAY' 'WILLIAMSBURG-CENTRAL' 'WILLIAMSBURG-EAST'
#  'WILLIAMSBURG-NORTH' 'ASTORIA' 'BAYSIDE' 'BREEZY POINT' 'COLLEGE POINT'
#  'CORONA' 'EAST ELMHURST' 'ELMHURST' 'FAR ROCKAWAY' 'FLORAL PARK'
#  'FLUSHING-NORTH' 'FLUSHING-SOUTH' 'FOREST HILLS' 'GLEN OAKS' 'GLENDALE'
#  'HILLCREST' 'HOLLIS' 'HOLLISWOOD' 'HOWARD BEACH' 'JACKSON HEIGHTS'
#  'JAMAICA ESTATES' 'JAMAICA HILLS' 'KEW GARDENS' 'LAURELTON' 'MASPETH'
#  'MIDDLE VILLAGE' 'OAKLAND GARDENS' 'OZONE PARK' 'QUEENS VILLAGE'
#  'REGO PARK' 'RICHMOND HILL' 'RIDGEWOOD' 'ROSEDALE'
#  'SO. JAMAICA-BAISLEY PARK' 'SOUTH JAMAICA' 'SOUTH OZONE PARK'
#  'SPRINGFIELD GARDENS' 'ST. ALBANS' 'WOODSIDE' 'ANNADALE' 'ARDEN HEIGHTS'
#  'BULLS HEAD' 'CONCORD' 'DONGAN HILLS' 'DONGAN HILLS-OLD TOWN'
#  'ELTINGVILLE' 'GRASMERE' 'GREAT KILLS' 'HUGUENOT' 'MANOR HEIGHTS'
#  'MARINERS HARBOR' 'MIDLAND BEACH' 'NEW BRIGHTON-ST. GEORGE'
#  'NEW SPRINGVILLE' 'OAKWOOD' 'PLEASANT PLAINS' 'PORT RICHMOND' 'ROSEBANK'
#  'ROSSVILLE' 'SOUTH BEACH' 'TOMPKINSVILLE' 'TOTTENVILLE'
#  'WEST NEW BRIGHTON' 'WESTERLEIGH' 'WILLOWBROOK' 'WOODROW' 'CIVIC CENTER'
#  'FINANCIAL' 'HARLEM-UPPER' 'INWOOD' 'KIPS BAY' 'SOHO' 'TRIBECA'
#  'BEDFORD PARK/NORWOOD' 'FIELDSTON' 'KINGSBRIDGE HTS/UNIV HTS'
#  'KINGSBRIDGE/JEROME PARK' 'MOTT HAVEN/PORT MORRIS'
#  'SCHUYLERVILLE/PELHAM BAY' 'THROGS NECK' 'WILLIAMSBRIDGE'
#  'BROOKLYN HEIGHTS' 'DOWNTOWN-METROTECH' 'GREENPOINT' 'MARINE PARK'
#  'NAVY YARD' 'SUNSET PARK' 'WILLIAMSBURG-SOUTH' 'WINDSOR TERRACE'
#  'WYCKOFF HEIGHTS' 'ARVERNE' 'BROAD CHANNEL' 'CAMBRIA HEIGHTS'
#  'FRESH MEADOWS' 'LITTLE NECK' 'LONG ISLAND CITY' 'ROCKAWAY PARK'
#  'SUNNYSIDE' 'WHITESTONE' 'WOODHAVEN' 'DONGAN HILLS-COLONY' 'EMERSON HILL'
#  'NEW DORP' 'STAPLETON' 'BAYCHESTER' 'CARROLL GARDENS' 'NEW BRIGHTON'
#  'ALPHABET CITY' 'HARLEM-EAST' 'LITTLE ITALY' 'MANHATTAN VALLEY'
#  'MORNINGSIDE HEIGHTS' 'MURRAY HILL' 'WASHINGTON HEIGHTS LOWER'
#  'WASHINGTON HEIGHTS UPPER' 'CITY ISLAND' 'EAST TREMONT' 'BRIGHTON BEACH'
#  'CLINTON HILL' 'COBBLE HILL' 'FLATLANDS' 'BEECHHURST' 'BELLE HARBOR'
#  'BELLEROSE' 'BRIARWOOD' 'DOUGLASTON' 'HAMMELS' 'CASTLETON CORNERS'
#  'CLOVE LAKES' 'GRANT CITY' 'NEW DORP-HEIGHTS' 'PORT IVORY' 'SILVER LAKE'
#  'TRAVIS' 'PELHAM GARDENS' 'BERGEN BEACH' 'CYPRESS HILLS' 'KENSINGTON'
#  'JAMAICA' 'ARROCHAR' 'CONCORD-FOX HILLS' 'GREAT KILLS-BAY TERRACE'
#  'NEW DORP-BEACH' 'CHINATOWN' 'ROOSEVELT ISLAND' 'PELHAM PARKWAY SOUTH'
#  'PRINCES BAY' 'HUNTS POINT' 'BOERUM HILL' 'BUSH TERMINAL' 'SEAGATE'
#  'ARROCHAR-SHORE ACRES' 'ROSSVILLE-CHARLESTON' 'STAPLETON-CLIFTON'
#  'TODT HILL' 'EAST VILLAGE' 'WOODLAWN' 'COBBLE HILL-WEST' 'MILL BASIN'
#  'HOLLIS HILLS' 'BATHGATE' 'CROTONA PARK' 'RED HOOK'
#  'FLUSHING MEADOW PARK' 'UPPER EAST SIDE (96-110)' 'OAKWOOD-BEACH'
#  'VAN CORTLANDT PARK' 'GRYMES HILL' 'RICHMONDTOWN' 'NEPONSIT' 'LIVINGSTON'
#  'FORDHAM' 'HARLEM-WEST' 'MANHATTAN-UNKNOWN' 'BRONX-UNKNOWN'
#  'CITY ISLAND-PELHAM STRIP' 'CO-OP CITY' 'BROOKLYN-UNKNOWN' 'SPRING CREEK'
#  'AIRPORT LA GUARDIA' 'JAMAICA BAY' 'QUEENS-UNKNOWN' 'BLOOMFIELD'
#  'RICHMONDTOWN-LIGHTHS HILL' 'ROSSVILLE-PORT MOBIL'
#  'ROSSVILLE-RICHMOND VALLEY']
#       neighbourhood_group                   building_class neighbourhood  \
# 24              Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 25              Manhattan  13 CONDOS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 1560            Manhattan  13 CONDOS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 2261            Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 2262            Manhattan  13 CONDOS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# ...                   ...                              ...           ...
# 18813           Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 18814           Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 18815           Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 18816           Manhattan   10 COOPS - ELEVATOR APARTMENTS   SOUTHBRIDGE
# 18817           Manhattan  13 CONDOS - ELEVATOR APARTMENTS   SOUTHBRIDGE
#
#        sale_price   sale_date   latitude  longitude  how_far_km
# 24        1100000  2018-12-06  40.708837 -74.005176    8.210741
# 25        1350000  2018-12-06  40.709749 -74.006792    8.209841
# 1560      1700000  2018-12-13  40.711541 -74.006027    8.116733
# 2261       650000  2018-12-17  40.708837 -74.005176    8.210741
# 2262       775000  2018-12-17  40.709749 -74.006792    8.209841
# ...           ...         ...        ...        ...         ...
# 18813      970000  2019-01-22  40.708275 -74.003556    8.202447
# 18814     1200000  2019-01-24  40.708275 -74.003556    8.202447
# 18815      660000  2019-01-28  40.708837 -74.005176    8.210741
# 18816           0  2019-01-29  40.708837 -74.005176    8.210741
# 18817     1109500  2019-01-31  40.707811 -74.003221    8.217361
#
# [101 rows x 8 columns]

# %%
#Define a new neighbourhood column to compare with neighbourhood data from sale
df['neigh_comp'] = df['neighbourhood']

#rename neighbour hood to match sale data
#some neighbourhood are not on the sale list, can assume name of nearby neighbourhood
replace = [
    ['CONCOURSE VILLAGE', 'CONCOURSE'],['WEST BRIGHTON', 'WEST NEW BRIGHTON'],
    ['KEW GARDENS HILLS', 'KEW GARDENS'], ['BAY TERRACE, STATEN ISLAND', 'BAY TERRACE'],
    ['WESTCHESTER SQUARE', 'WESTCHESTER'],["BULL'S HEAD", 'BULLS HEAD'],
    ["NEW DORP BEACH", 'NEW DORP-BEACH'],["BEDFORD-STUYVESANT", 'BEDFORD STUYVESANT'],
    ["EAST HARLEM", 'HARLEM-EAST'],["FLATIRON DISTRICT", 'FLATIRON'],
    ["NORTH RIVERDALE", 'RIVERDALE'],["EAST MORRISANIA", 'MORRISANIA'],
    ["EAST FLATBUSH", 'FLATBUSH-EAST'],["PRINCE'S BAY", 'PRINCES BAY'],
    ["PRINCE'S BAY", 'PRINCES BAY'],["FINANCIAL DISTRICT", 'FINANCIAL'],
    ["SOUTH SLOPE", 'PARK SLOPE SOUTH'],["HELL'S KITCHEN", 'MIDTOWN WEST'],
    ["WEST VILLAGE", 'GREENWICH VILLAGE'],['NOLITA','LITTLE ITALY'],
    ['PROSPECT-LEFFERTS GARDENS','PROSPECT HEIGHTS'],['ROCKAWAY BEACH','ROCKAWAY PARK'],
    ['BAYSWATER','FAR ROCKAWAY'], ['EASTCHESTER', 'WESTCHESTER'],
    ['DITMARS STEINWAY','ASTORIA'],['THEATER DISTRICT','MIDTOWN WEST'],
    ['EDGEMERE','ROCKAWAY PARK'], ['COLUMBIA ST', 'LOWER EAST SIDE'],
    ['BATTERY PARK CITY','FINANCIAL'],['TWO BRIDGES','SOUTHBRIDGE'],
    ['STUYVESANT TOWN','GRAMERCY'],['UNIVERSITY HEIGHTS',"KINGSBRIDGE HTS/UNIV HTS"],
    ['MARBLE HILL', 'KINGSBRIDGE/JEROME PARK'],['NOHO','EAST VILLAGE'],
    ['RANDALL MANOR','WEST NEW BRIGHTON'],['GRANITEVILLE','MARINERS HARBOR'],
    ['HOWLAND HOOK','BLOOMFIELD'],['LIGHTHOUSE HILL','RICHMONDTOWN-LIGHTHS HILL'],
    ['VINEGAR HILL','NAVY YARD'], ['DUMBO','DOWNTOWN-FULTON FERRY'],
    ['SEA GATE', 'CONEY ISLAND'],['DOWNTOWN BROOKLYN','DOWNTOWN-FULTON MALL'],
    ['FORT HAMILTON','DYKER HEIGHTS'],['OLINVILLE', 'WILLIAMSBRIDGE'],
    ['CLAREMONT','VILLAGE MORRISANIA'], ['ALLERTON','PELHAM PARKWAY NORTH'],
    ['SPUYTEN DUYVIL','RIVERDALE'],['EDENWALD','WESTCHESTER'],
    ['WEST FARMS','CROTONA PARK'],['CLASON POINT', 'SOUNDVIEW']   
]

# %%
#DETERMINE MEDIAN PRICE OF PROPERTY IN EACH NEIGHBOURHOOD
df['neighbourhood'] = df['neighbourhood'].str.upper()

neighbour_list = df['neighbourhood'].to_list()
neighbour_list = set(neighbour_list)
neighbour_dict = {}

for item in neighbour_list:       
    temp_list = []
    for index, row in df2.iterrows():
        
        if item in row['neighbourhood']:
            price = row['sale_price']
            temp_list.append(price)
            
    neighbour_dict[item]= temp_list
    if len(temp_list) == 0:
        print(item)
# Out:
# NOLITA
# CLAREMONT VILLAGE
# CLASON POINT
# EASTCHESTER
# VINEGAR HILL
# RANDALL MANOR
# TWO BRIDGES
# WEST VILLAGE
# HELL'S KITCHEN
# GRANITEVILLE
# NOHO
# MARBLE HILL
# OLINVILLE
# PROSPECT-LEFFERTS GARDENS
# FLATIRON DISTRICT
# UNIVERSITY HEIGHTS
# EAST MORRISANIA
# BAYSWATER
# FINANCIAL DISTRICT
# SOUTH SLOPE
# BATTERY PARK CITY
# FORT HAMILTON
# EAST FLATBUSH
# SEA GATE
# STUYVESANT TOWN
# PRINCE'S BAY
# WEST FARMS
# EAST HARLEM
# NORTH RIVERDALE
# EDGEMERE
# ALLERTON
# BEDFORD-STUYVESANT
# NEW DORP BEACH
# SPUYTEN DUYVIL
# ROCKAWAY BEACH
# EDENWALD
# COLUMBIA ST
# THEATER DISTRICT
# DUMBO
# BULL'S HEAD
# WESTCHESTER SQUARE
# DOWNTOWN BROOKLYN
# DITMARS STEINWAY
# BAY TERRACE, STATEN ISLAND
# LIGHTHOUSE HILL
# KEW GARDENS HILLS
# HOWLAND HOOK
# WEST BRIGHTON
# CONCOURSE VILLAGE

# %%
df2
# Out:
#       neighbourhood_group                   building_class neighbourhood  \
# 0               Manhattan  13 CONDOS - ELEVATOR APARTMENTS       CHELSEA
# 1               Manhattan                   17 CONDO COOPS       CHELSEA
# 2               Manhattan   10 COOPS - ELEVATOR APARTMENTS       CLINTON
# 3               Manhattan  13 CONDOS - ELEVATOR APARTMENTS       FASHION
# 4               Manhattan  13 CONDOS - ELEVATOR APARTMENTS      FLATIRON
# ...                   ...                              ...           ...
# 73239       Staten Island          01 ONE FAMILY DWELLINGS       WOODROW
# 73240       Staten Island          02 TWO FAMILY DWELLINGS       WOODROW
# 73241       Staten Island          02 TWO FAMILY DWELLINGS       WOODROW
# 73242       Staten Island          02 TWO FAMILY DWELLINGS       WOODROW
# 73243       Staten Island          02 TWO FAMILY DWELLINGS       WOODROW
#
#        sale_price   sale_date   latitude  longitude  how_far_km
# 0         5200000  2018-12-06  40.742107 -73.998510    7.454557
# 1          540000  2018-12-06  40.745466 -73.998917    7.501481
# 2          336648  2018-12-06  40.768225 -73.986419    7.868896
# 3              10  2018-12-06  40.750038 -73.983409    7.270112
# 4          545000  2018-12-06  40.742021 -73.986742    7.239504
# ...           ...         ...        ...        ...         ...
# 73239           0  2019-01-25  40.539191 -74.222818   30.246898
# 73240      590000  2019-01-11  40.536236 -74.209270   29.721766
# 73241           0  2019-01-31  40.535069 -74.215249   30.141944
# 73242           0  2019-01-24  40.539712 -74.215793   29.808690
# 73243      630000  2019-01-03  40.540793 -74.219146   29.914788
#
# [73244 rows x 8 columns]

# %%
#DETERMINE MEDIAN PRICE OF PROPERTY IN EACH NEIGHBOURHOOD GROUP

#split into neighbourhood_group

br_sale = df2.loc[df2["neighbourhood_group"] == 'Bronx']
bk_sale = df2.loc[df2["neighbourhood_group"] == 'Brooklyn']
mn_sale = df2.loc[df2["neighbourhood_group"] == 'Manhattan']
qn_sale = df2.loc[df2["neighbourhood_group"] == 'Queens']
si_sale = df2.loc[df2["neighbourhood_group"] == 'Staten Island']

br_med_cost = br_sale['sale_price'].median()
bk_med_cost = bk_sale['sale_price'].median()
mn_med_cost = mn_sale['sale_price'].median()
qn_med_cost = qn_sale['sale_price'].median()
si_med_cost = si_sale['sale_price'].median()

# %%
#DEFINE COST OR MORTGAGE RATE
#THIS WILL BE DETERMINED BASED ON SALE_PRICE
#i.e. total sale price will determine total mortgage

#Assuming fixed annual interest rate

def mortgage_calculator(p, i, n):
    
    '''
    The function calculate the periodic payment
    input: initial payment p, fixed annual interest rate i, total number of payment n
    output: perdioc payment amount
    Example:
        initial payment: p = 500,000
        fixed annual interest rate: i = 2.75
        30-year-loan with yearly payment: n = 30
    '''
    
    if i > 0: 
        A = p * i / ( 1 - ( 1 + i ) ** (-n) )
    elif i == 0:
        A = p / n
    else:
        print("print please input positive anual interest rate i")
    return A   

#assume current fixed annual interest rate for 30year loan
#assume median price per neighbourhood as initial cost
n = 30
i = 0.031

#add a mortgage column
# create a list of our conditions
conditions = [
    (df['neighbourhood_group'] == 'Brooklyn'),
    (df['neighbourhood_group'] == 'Bronx'),
    (df['neighbourhood_group'] == 'Manhattan'),
    (df['neighbourhood_group'] == 'Queens'),
    (df['neighbourhood_group'] == 'Staten Island')
    ]

# create a list of the values we want to assign for each condition
values = [mortgage_calculator(bk_med_cost, i, n),
         mortgage_calculator(br_med_cost, i, n),
         mortgage_calculator(mn_med_cost, i, n),
         mortgage_calculator(qn_med_cost, i, n),
         mortgage_calculator(si_med_cost, i, n)]

# create a new column and use np.select to assign values to it using our lists as arguments
df['annual_mortgage'] = np.select(conditions, values)

# %%
#divide into types of houses
shared_room = df.loc[df['room_type'] == 'Shared room']
apt = df.loc[df['room_type'] == 'Entire home/apt']
private_room = df.loc[df['room_type'] == 'Private room']

# %%
#PLOT ANNUAL MORTGAGE VS ANNUAL EARN


fig = plt.figure(num=None, figsize=(20, 8), dpi=80, facecolor='w', edgecolor='k')
fig.subplots_adjust(top=0.8)

### SHARED ROOM
ax1 = fig.add_subplot(131)
ax1 = sns.scatterplot(shared_room.annual_mortgage, shared_room.annual_earn, hue = shared_room.neighbourhood_group)
ax1.get_legend().remove()

plt.plot(x,y)
plt.title('Shared Room Annual Earning vs Annual Mortgage')
plt.xlabel('Annual earning / $')
plt.ylabel('Annual mortgage / $')
plt.grid(alpha=.4,linestyle='--')

box = ax1.get_position()
ax1.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])


### PRIVATE ROOM
ax2 = fig.add_subplot(132)
ax2 = sns.scatterplot(private_room.annual_mortgage, private_room.annual_earn, hue = private_room.neighbourhood_group)

plt.plot(x,y)

plt.title('Private Room Annual Earning vs Annual Mortgage')
plt.xlabel('Annual earning / $')
plt.ylabel('Annual mortgage / $')
plt.grid(alpha=.4,linestyle='--')

# Shrink current axis's height by 10% on the bottom
box = ax2.get_position()
ax2.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=5)


### ENTIRE HOME
ax3 = fig.add_subplot(133)
ax3 = sns.scatterplot(apt.annual_mortgage, apt.annual_earn, hue = apt.neighbourhood_group)
ax3.get_legend().remove()

plt.plot(x,y)
plt.title('Entire Home Annual Earning vs Annual Mortgage')
plt.xlabel('Annual earning / $')
plt.ylabel('Annual mortgage / $')
plt.grid(alpha=.4,linestyle='--')

box = ax3.get_position()
ax3.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

plt.show()

# %%
# plot location in relation to Neighbourhood group 
title = 'Neighbourhood Group Location'
plt.figure(figsize=(10,6))
sns.scatterplot(data.longitude,data.latitude,hue=data.neighbourhood_group).set_title(title)
plt.ioff()

# %%
sns.set(style="white", palette="muted", color_codes=True)

title = ""
sns.catplot(x='neighbourhood_group', kind="count", hue="room_type", data=df)
